# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./data/fifa23.csv')
df.head()
# Out:
#          Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0        L. Messi        Lionel Messi       91         91        54000000
# 1      K. Benzema       Karim Benzema       91         91        64000000
# 2  R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3    K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4       K. Mbappé       Kylian Mbappé       91         95       190500000
#
#   Positions Played Best Position Nationality  \
# 0               RW           CAM   Argentina
# 1            CF,ST            CF      France
# 2               ST            ST      Poland
# 3           CM,CAM            CM     Belgium
# 4            ST,LW            ST      France
#
#                                          Image Link  Age  ...  LM Rating  \
# 0  https://cdn.sofifa.net/players/158/023/23_60.png   35  ...         91
# 1  https://cdn.sofifa.net/players/165/153/23_60.png   34  ...         89
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18539 entries, 0 to 18538
# Data columns (total 89 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Known As                     18539 non-null  object
#  1   Full Name                    18539 non-null  object
#  2   Overall                      18539 non-null  int64
#  3   Potential                    18539 non-null  int64
#  4   Value(in Euro)               18539 non-null  int64
#  5   Positions Played             18539 non-null  object
#  6   Best Position                18539 non-null  object
#  7   Nationality                  18539 non-null  object
#  8   Image Link                   18539 non-null  object
#  9   Age                          18539 non-null  int64
#  10  Height(in cm)                18539 non-null  int64
#  11  Weight(in kg)                18539 non-null  int64
#  12  TotalStats                   18539 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['Known As', 'Full Name', 'Overall', 'Potential', 'Value(in Euro)',
#        'Positions Played', 'Best Position', 'Nationality', 'Image Link', 'Age',
#        'Height(in cm)', 'Weight(in kg)', 'TotalStats', 'BaseStats',
#        'Club Name', 'Wage(in Euro)', 'Release Clause', 'Club Position',
#        'Contract Until', 'Club Jersey Number', 'Joined On', 'On Loan',
#        'Preferred Foot', 'Weak Foot Rating', 'Skill Moves',
#        'International Reputation', 'National Team Name',
#        'National Team Image Link', 'National Team Position',
#        'National Team Jersey Number', 'Attacking Work Rate',
#        'Defensive Work Rate', 'Pace Total', 'Shooting Total', 'Passing Total',
#        'Dribbling Total', 'Defending Total', 'Physicality Total', 'Crossing',
#        'Finishing', 'Heading Accuracy', 'Short Passing', 'Volleys',
#        'Dribbling', 'Curve', 'Freekick Accuracy', 'LongPassing', 'BallControl',
# ...

# %%
df.dropna(inplace=True)
df.drop_duplicates(inplace=True)
df.fillna(df.mean(), inplace=True)
# Out:
# C:\Users\alberespi\AppData\Local\Temp\ipykernel_37596\3614303467.py:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(), inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18420 entries, 0 to 18538
# Data columns (total 89 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Known As                     18420 non-null  object
#  1   Full Name                    18420 non-null  object
#  2   Overall                      18420 non-null  int64
#  3   Potential                    18420 non-null  int64
#  4   Value(in Euro)               18420 non-null  int64
#  5   Positions Played             18420 non-null  object
#  6   Best Position                18420 non-null  object
#  7   Nationality                  18420 non-null  object
#  8   Image Link                   18420 non-null  object
#  9   Age                          18420 non-null  int64
#  10  Height(in cm)                18420 non-null  int64
#  11  Weight(in kg)                18420 non-null  int64
#  12  TotalStats                   18420 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['Known As', 'Full Name', 'Overall', 'Potential', 'Value(in Euro)',
#        'Positions Played', 'Best Position', 'Nationality', 'Image Link', 'Age',
#        'Height(in cm)', 'Weight(in kg)', 'TotalStats', 'BaseStats',
#        'Club Name', 'Wage(in Euro)', 'Release Clause', 'Club Position',
#        'Contract Until', 'Club Jersey Number', 'Joined On', 'On Loan',
#        'Preferred Foot', 'Weak Foot Rating', 'Skill Moves',
#        'International Reputation', 'National Team Name',
#        'National Team Image Link', 'National Team Position',
#        'National Team Jersey Number', 'Attacking Work Rate',
#        'Defensive Work Rate', 'Pace Total', 'Shooting Total', 'Passing Total',
#        'Dribbling Total', 'Defending Total', 'Physicality Total', 'Crossing',
#        'Finishing', 'Heading Accuracy', 'Short Passing', 'Volleys',
#        'Dribbling', 'Curve', 'Freekick Accuracy', 'LongPassing', 'BallControl',
# ...

# %%
df.drop(columns={'Positions Played', 'Image Link', 'Release Clause', 'Club Position',
                 'Contract Until', 'Club Jersey Number', 'Joined On', 'On Loan', 
                 'National Team Name', 'National Team Image Link', 'National Team Position', 
                 'National Team Jersey Number', 'Value(in Euro)', 'Wage(in Euro)'}, inplace=True)

# %%
df.columns
# Out:
# Index(['Known As', 'Full Name', 'Overall', 'Potential', 'Best Position',
#        'Nationality', 'Age', 'Height(in cm)', 'Weight(in kg)', 'TotalStats',
#        'BaseStats', 'Club Name', 'Preferred Foot', 'Weak Foot Rating',
#        'Skill Moves', 'International Reputation', 'Attacking Work Rate',
#        'Defensive Work Rate', 'Pace Total', 'Shooting Total', 'Passing Total',
#        'Dribbling Total', 'Defending Total', 'Physicality Total', 'Crossing',
#        'Finishing', 'Heading Accuracy', 'Short Passing', 'Volleys',
#        'Dribbling', 'Curve', 'Freekick Accuracy', 'LongPassing', 'BallControl',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
#        'Composure', 'Marking', 'Standing Tackle', 'Sliding Tackle',
#        'Goalkeeper Diving', 'Goalkeeper Handling', ' GoalkeeperKicking',
# ...

# %%
non_numeric_columns = df.select_dtypes(exclude='number').columns
print(non_numeric_columns)
# Out:
# Index(['Known As', 'Full Name', 'Best Position', 'Nationality', 'Club Name',
#        'Preferred Foot', 'Attacking Work Rate', 'Defensive Work Rate'],
#       dtype='object')

# %%
unique_values_pf = df['Preferred Foot'].unique()
print(unique_values_pf)
# Out:
# ['Left' 'Right']

# %%
df["Preferred Foot"].replace({"Left": 0, "Right": 1}, inplace=True)

# %%
unique_values_pf = df['Preferred Foot'].unique()
print(unique_values_pf)
# Out:
# [0 1]

# %%
unique_values_awr = df['Attacking Work Rate'].unique()
unique_values_dwr = df['Defensive Work Rate'].unique()

print("-- Attacking Work Rates --")
print(unique_values_awr)

print("\n-- Defensive Work Rate --")
print(unique_values_dwr)
# Out:
# -- Attacking Work Rates --
# ['Low' 'Medium' 'High']
#
# -- Defensive Work Rate --
# ['Low' 'Medium' 'High']

# %%
df_encoded = pd.get_dummies(df, columns=["Attacking Work Rate", "Defensive Work Rate"])
df_encoded
# Out:
#              Known As           Full Name  Overall  Potential Best Position  \
# 0            L. Messi        Lionel Messi       91         91           CAM
# 1          K. Benzema       Karim Benzema       91         91            CF
# 2      R. Lewandowski  Robert Lewandowski       91         91            ST
# 3        K. De Bruyne     Kevin De Bruyne       91         91            CM
# 4           K. Mbappé       Kylian Mbappé       91         95            ST
# ...               ...                 ...      ...        ...           ...
# 18534      D. Collins      Darren Collins       47         56           CAM
# 18535    Yang Dejiang        Dejiang Yang       47         57           CDM
# 18536       L. Mullan         Liam Mullan       47         67            RM
# 18537    D. McCallion    Daithí McCallion       47         61            CB
# 18538        N. Rabha         Nabin Rabha       47         50            LB
#
# ...

# %%
df_encoded.columns
# Out:
# Index(['Known As', 'Full Name', 'Overall', 'Potential', 'Best Position',
#        'Nationality', 'Age', 'Height(in cm)', 'Weight(in kg)', 'TotalStats',
#        'BaseStats', 'Club Name', 'Preferred Foot', 'Weak Foot Rating',
#        'Skill Moves', 'International Reputation', 'Pace Total',
#        'Shooting Total', 'Passing Total', 'Dribbling Total', 'Defending Total',
#        'Physicality Total', 'Crossing', 'Finishing', 'Heading Accuracy',
#        'Short Passing', 'Volleys', 'Dribbling', 'Curve', 'Freekick Accuracy',
#        'LongPassing', 'BallControl', 'Acceleration', 'Sprint Speed', 'Agility',
#        'Reactions', 'Balance', 'Shot Power', 'Jumping', 'Stamina', 'Strength',
#        'Long Shots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeper Diving', 'Goalkeeper Handling',
#        ' GoalkeeperKicking', 'Goalkeeper Positioning', 'Goalkeeper Reflexes',
# ...

# %%
df_categorical = df_encoded.select_dtypes(exclude=['number'])
df_numeric = df_encoded.select_dtypes(include='number')

# %%
df_categorical
# Out:
#              Known As           Full Name Best Position          Nationality  \
# 0            L. Messi        Lionel Messi           CAM            Argentina
# 1          K. Benzema       Karim Benzema            CF               France
# 2      R. Lewandowski  Robert Lewandowski            ST               Poland
# 3        K. De Bruyne     Kevin De Bruyne            CM              Belgium
# 4           K. Mbappé       Kylian Mbappé            ST               France
# ...               ...                 ...           ...                  ...
# 18534      D. Collins      Darren Collins           CAM  Republic of Ireland
# 18535    Yang Dejiang        Dejiang Yang           CDM             China PR
# 18536       L. Mullan         Liam Mullan            RM     Northern Ireland
# 18537    D. McCallion    Daithí McCallion            CB  Republic of Ireland
# 18538        N. Rabha         Nabin Rabha            LB                India
#
#                  Club Name
# ...

# %%
df_numeric
# Out:
#        Overall  Potential  Age  Height(in cm)  Weight(in kg)  TotalStats  \
# 0           91         91   35            169             67        2190
# 1           91         91   34            185             81        2147
# 2           91         91   33            185             81        2205
# 3           91         91   31            181             70        2303
# 4           91         95   23            182             73        2177
# ...        ...        ...  ...            ...            ...         ...
# 18534       47         56   21            174             68        1287
# 18535       47         57   17            175             60        1289
# 18536       47         67   18            170             65        1333
# 18537       47         61   17            178             65        1113
# 18538       47         50   25            176             66        1277
#
#        BaseStats  Preferred Foot  Weak Foot Rating  Skill Moves  ...  \
# ...

# %%
df_numeric.rename(columns={' GoalkeeperKicking': 'Goalkeeper Kicking'}, inplace=True)

# %%
df_numeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18420 entries, 0 to 18538
# Data columns (total 74 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Overall                     18420 non-null  int64
#  1   Potential                   18420 non-null  int64
#  2   Age                         18420 non-null  int64
#  3   Height(in cm)               18420 non-null  int64
#  4   Weight(in kg)               18420 non-null  int64
#  5   TotalStats                  18420 non-null  int64
#  6   BaseStats                   18420 non-null  int64
#  7   Preferred Foot              18420 non-null  int64
#  8   Weak Foot Rating            18420 non-null  int64
#  9   Skill Moves                 18420 non-null  int64
#  10  International Reputation    18420 non-null  int64
#  11  Pace Total                  18420 non-null  int64
#  12  Shooting Total              18420 non-null  int64
# ...

# %%
#df_categorical.to_csv('./data/fifa23_cat_clean.csv', index=False)
#df_numeric.to_csv('./data/fifa23_num_clean.csv', index=False)
